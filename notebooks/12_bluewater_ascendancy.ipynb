# %% [markdown]
# # Bluewater Ascendancy: Teaching Empire: Total War to Care About the Sea
#
# This article has no accompanying analysis notebook.
#
# Bluewater Ascendancy is a personal rebalance mod for Empire: Total War, not a data-analysis piece — there is no dataset, notebook, or source data behind it. The full write-up lives in `articles/12_bluewater_ascendancy/article.md`.
